# %%
import numpy as np

# %%
cA = np.array([[1,1,0],[1,2,-1],[0,-1,4]])
cA
# Out:
# array([[ 1,  1,  0],
#        [ 1,  2, -1],
#        [ 0, -1,  4]])

# %%
y_data = np.array([[0, 0], [1, 0]])
w1 = np.array([[1], [-1]])
w2 = np.array([[1, -1],
               [0, 1]])

# %%
1/(1+np.exp(2*0))
# Out:
# 0.5

# %%
(1/(1+np.exp(2*0)))*(1+(1/(1+np.exp(2*0))))
# Out:
# 0.75

# %%
np.array([0.75,1.25]) @ w2
# Out:
# array([0.75, 0.5 ])

# %%
-(-0.5**2)+1
# Out:
# 1.25

# %%
np.array([[0.5],[0.5]])@ np.array([0.75,0.75])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 np.array([[0.5],[0.5]])@ np.array([0.75,0.75])
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
